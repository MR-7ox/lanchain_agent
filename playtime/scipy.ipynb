# %%
import numpy as np
from scipy.io.wavfile import write

fs = 440
time = 5

t= np.linspace(0, time, fs * time, endpoint=False)
data = np.sin(2 * np.pi * 440 * t)

write("output.wav", fs, data)

# %%
from scipy.io.wavfile import read

fs, audio = read("output.wav")

print("Sample rate:", fs)
print("Samples:", len(audio))
print("Data type:", audio.dtype)
# Out:
# Sample rate: 440
# Samples: 2200
# Data type: float64
