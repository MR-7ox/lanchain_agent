# %%
import sys

# %%
print(sys.argv)
# Out:
# ['/home/Deva/backup/mr7ox/courses/LANGCHAIN/agents/lib/python3.14/site-packages/ipykernel_launcher.py', '--f=/run/user/1000/jupyter/runtime/kernel-v33083327606ee0e0bb7079db6eb7520a9a4ba4a88.json']

# %%
sys.exit()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /home/Deva/backup/mr7ox/courses/LANGCHAIN/agents/lib/python3.14/site-packages/IPython/core/interactiveshell.py:3831: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
print(sys.path)
# Out:
# ['/usr/lib/python314.zip', '/usr/lib/python3.14', '/usr/lib/python3.14/lib-dynload', '', '/home/Deva/backup/mr7ox/courses/LANGCHAIN/agents/lib/python3.14/site-packages']

# %%
sys.version
# Out:
# '3.14.7 (main, Aug 10 2026, 07:46:56) [GCC 16.1.1 20260728]'

# %%
sys.version_info
# Out:
# sys.version_info(major=3, minor=14, micro=7, releaselevel='final', serial=0)

# %%
sys.platform
# Out:
# 'linux'

# %%
sys.stdin
# Out:
# <_io.TextIOWrapper name='<stdin>' mode='r' encoding='utf-8'>
