# %%
import time

# %%
print(time.time())
# Out:
# 1789720572.052081

# %%
import time

print("Start")

time.sleep(2)

print("End")
# Out:
# Start
# End

# %%
for i in range(5):
    print(i)
    time.sleep(1)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
import time

start = time.time()

# code
time.sleep(2)

end = time.time()

print("Time taken:", end - start)
# Out:
# Time taken: 2.000234365463257

# %%
from tqdm import tqdm

for i in tqdm(range(100)):
    time.sleep(0.01)
# Out:
# 100%|██████████| 100/100 [00:01<00:00, 98.53it/s]

# %%
duration = 50
for _ in tqdm(range(duration * 10)):
    time.sleep(0.1)
# Out:
#  26%|██▌       | 130/500 [00:13<00:37,  9.88it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 duration = 50
#       2 for _ in tqdm(range(duration * 10)):
# ----> 3     time.sleep(0.1)
#
# KeyboardInterrupt:

# %%
import io

# %%
import io

data = b"Hello World"

buffer = io.BytesIO(data)

print(buffer.read())
# Out:
# b'Hello World'
