# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool
from typing import Dict, Any
from firecrawl import Firecrawl


firecrawl_client = Firecrawl()

@tool
def web_search(query: str) -> list[Dict[str, Any]]:

    """Search the web for information"""

    return firecrawl_client.search(query)

# %%
system_prompt = """

You are a personal chef. The user will give you a list of ingredients they have left over in their house.

Using the web search tool, search the web for recipes that can be made with the ingredients they have.

Return recipe suggestions and eventually the recipe instructions to the user, if requested.

"""

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="gemini-3.5-flash-lite",

    model_provider="google_genai"
)

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    model= model ,
    tools=[web_search],
    system_prompt=system_prompt,
    checkpointer=InMemorySaver()
)

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    model = model,
    tools = [web_search],
    system_prompt = system_prompt,
    checkpointer = InMemorySaver()

)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [HumanMessage(content="I have some leftover chicken and rice. What can I make?")]},
    config
)

print(response['messages'][-1].content)
# Out:
# [{'type': 'text', 'text': 'It looks like we are on the same page! Since you already have your leftover chicken and rice ready to go, which of those three ideas sounds best to you? \n\n*   **Chicken Fried Rice** (Quick, savory, and customizable)\n*   **Cheesy Chicken and Rice Casserole** (Warm, creamy comfort food)\n*   **Chicken Rice Soup / Arroz Caldo** (Soothing and broth-y)\n\nOr, if you have a few other random veggies or sauces sitting in your fridge (like soy sauce, eggs, frozen peas, broccoli, cheese, or broth), tell me what they are, and we can build a custom recipe just for you!', 'extras': {'signature': 'El4KXAERTTIPYNaDqMqPLvPvJXcGeYB7Nskx/mt4d/C3PdA4REJh98RWSQ2PhgewyIYojhRZRskVkbN3qJTCpb1FJ3dd1ZAQWF52jve0dkgxj0BzYC3TlGo+Ph3bEeJg'}}]

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='I have some leftover chicken and rice. What can I make?', additional_kwargs={}, response_metadata={}, id='092e9417-72cb-4bb5-9610-a3bc506cd541'),
#               AIMessage(content=[], additional_kwargs={'function_call': {'name': 'web_search', 'arguments': '{"query": "leftover chicken and rice recipes easy"}'}, '__gemini_function_call_thought_signatures__': {'call_80945': 'El4KXAERTTIPWVgPDPjK9MR3xqFPspnss1GhaoLObDCePPj9Ps44/PRKSM9hoOe8cwPd5dD8H6OIn1BiLfm4qaC3GXj/2sp/WXqT9eJ/Phic1dDWFmA0YLm1WaLxSMQj'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a0b0a8-f277-7e50-8942-3b6ced0547a7-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'leftover chicken and rice recipes easy'}, 'id': 'call_80945', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 119, 'output_tokens': 22, 'total_tokens': 141, 'input_token_details': {'cache_read': 0}}),
#               ToolMessage(content='web=[SearchResultWeb(url=\'https://www.crazyforcrust.com/chicken-and-rice-casserole/\', title=\'EASY Chicken and Rice Casserole - Crazy for Crust\', description=\'Rating 5.0(362) · 35 minJun 27, 2026 · Easy Chicken and Rice Casserole is an fast comfort food dinner. Use leftover chicken or turkey and rice to make this cheesy chicken casserole ...\', position=1, category=None), SearchResultWeb(url=\'https://iowagirleats.com/one-pot-chicken-and-rice/\', title=\'One Pot Chicken and Rice - Family Favorite Recipe - Iowa Girl Eats\', description=\'# One Pot Chicken and Rice\\n## Storing and Reheating\\nSimply scoop the cold chicken and rice into a bowl from the refrigerator then reheat in the microwave in 30 second increments, stirring between increments until warmed through.\', position=2, category=None), SearchResultWeb(url=\'https://www.easypeasyfoodie.com/leftover-chicken-egg-fried-rice/\', title=\'Leftover Chicken and Egg Fried Rice - Easy Peasy Foodie\', description=\'Rating 5.0(14) · 15 minAn easy, quick and family friendly meal, Leftover Chicken and Egg Fried Rice is perfect for a busy weeknight and a great way to use up your roast chicken ...\', position=3, category=None), SearchResultWeb(url=\'https://www.facebook.com/TheRecipeCritic/posts/-comment-recipe-for-the-easiest-dinner-using-leftovers-toss-leftover-chicken-and/1607847614020920/\', title=\'Comment RECIPE for the easiest dinner using leftovers! Toss leftover ...\', description="It\'s so easy to turn leftover rice, veggies, and shredded chicken into this family-loved chicken fried rice. Recipe link below · No photo ...", position=4, category=None), SearchResultWeb(url=\'https://www.thecountrycook.net/chicken-and-rice-casserole/\', title=\'Chicken and Rice Casserole - The Country Cook\', description=\'_**Rotisserie chicken in a creamy, rice filling topped with buttery bread crumbs**!_\\n\\n## Chicken and Rice Casserole\\nRotisserie chicken in a creamy, rice filling topped with bread crumbs!\', position=5, category=None), SearchResultWeb(url=\'https://quickweeknightmeals.com/chicken-fried-rice/\', title=\'Chicken Fried Rice - Quick Weeknight Meals\', description=\'Rating 4.8(6) · 15 minAug 27, 2024 · Simple and delicious Chicken Fried Rice is perfect for a weeknight! Use leftover chicken and rice to make this easy one pan dinner.\', position=6, category=None), SearchResultWeb(url=\'https://www.campbells.com/recipes/15-minute-chicken-rice-dinner/\', title="Campbell\'s 15-Minute Chicken & Rice Dinner - Recipes", description="## Newsletter Sign Up\\nThis 15-Minute Chicken & Rice Dinner recipe is so quick and easy, no one will even have time to ask, What\'s for dinner?\\n\\n## Instructions\\n- Tips\\n  - _Want to make enough to serve 8?_\\xa0 Use a 22.6-ounce can of Campbell\'s® Condensed Cream of Chicken Soup and double the remaining ingredients. Cook in a 6-quart saucepan\\xa0_(you\'ll need to brown the chicken in 2 batches- if you do it all at once it won\'t brown as well)_.\\xa0 For creamier rice, reduce the doubled amount of rice from 4 to 3 cups.\\n\\n## Reviews\\n### Delicious and easy.\\nChicken and rice\\n\\nI steamed some rice in chicken broth and ladeled the sauce over the rice and placed chicken on top.", position=7, category=None), SearchResultWeb(url=\'https://www.youtube.com/watch?v=71XwSdiJlDA\', title=\'Leftover Chicken Recipe (One Pot Chicken and Rice) - YouTube\', description="... leftover chicken into a mouthwatering meal with this easy one pot chicken and rice recipe! In this video, we\'ll show you how to take those ...", position=8, category=None), SearchResultWeb(url=\'https://www.laurafuentes.com/rotisserie-chicken-and-rice/\', title=\'Rotisserie Chicken and Rice (Easy 30-Minute One-Pan Dinner)\', description=\'Rating 5.0(25) · 30 minAug 10, 2026 · Make this easy rotisserie chicken and rice in one skillet with leftover rotisserie chicken, rice, tomatoes, and vegetables in 30 minutes.\', position=9, category=None), S ...
#               AIMessage(content=[{'type': 'text', 'text': "Leftover chicken and rice are the ultimate kitchen jackpot because they are a huge head-start for a quick, delicious meal. Since they are already cooked, you can whip up dinner in just 10 to 15 minutes!\n\nHere are three great ways to use them:\n\n1. **Quick Chicken Fried Rice (Fastest & Easiest)**\n   * *The Vibe:* Takeout at home, ready in 15 minutes.\n   * *How:* Toss cold leftover rice into a hot skillet or wok with a little oil, butter, or sesame oil. Add your diced chicken, some frozen peas and carrots, and a splash of soy sauce. Push everything to the side, scramble an egg in the empty space of the pan, and mix it all together. \n\n2. **Cheesy Chicken and Rice Casserole (Comfort Food)**\n   * *The Vibe:* Warm, creamy, and cozy.\n   * *How:* Mix your chopped chicken and rice with a can of cream of chicken (or mushroom) soup, a splash of milk or chicken broth, and plenty of shredded cheddar cheese. Pour it into a baking dish, top with a little extra cheese or crushed breadcrumbs/crackers, and bake at 350°F (175°C) until bubbly and golden.\n\n3. **Arroz Caldo or Chicken Rice Soup (Healing & Savory)**\n   * *The Vibe:* A soothing, savory bowl of soup.\n   * *How:* Sauté some garlic, ginger, and onion in a pot. Add chicken broth and bring to a simmer. Stir in your already-cooked rice and shredded chicken just until heated through. Top with green onions, a drizzle of fish sauce or soy sauce, and crispy garlic.\n\nDo any of these sound good to you? Let me know which one you'd like to make, and I can give you the exact step-by-step recipe (plus we can check if you have any other random ingredients in your fridge to toss in)!", 'extras': {'signature': 'El4KXAERTTIPcZIyosMpbYf/TK84ZF+nDHSvrzIxq9cQr9FbPzPOP2jtq8wbxJMpUYhLohXouoTsC9W+8geuiH+2+s6wzZNIs6hFOWKNPc2/nbnZTy913QULQy+T6oN3'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a0b0a9-03cf-7181-82fc-5e637b89b653-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1330, 'output_tokens': 423, 'total_tokens': 1753, 'input_token_details': {'cache_read': 0}})]}
